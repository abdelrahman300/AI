# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Airline_Delay_Cause.csv')
data.head()
# Out:
#    year  month carrier       carrier_name airport  \
# 0  2022      5      9E  Endeavor Air Inc.     ABE
# 1  2022      5      9E  Endeavor Air Inc.     ABY
# 2  2022      5      9E  Endeavor Air Inc.     ACK
# 3  2022      5      9E  Endeavor Air Inc.     AEX
# 4  2022      5      9E  Endeavor Air Inc.     AGS
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...        136.0        7.0
# 1             Albany, GA: Southwest Georgia Regional         91.0       16.0
# 2                  Nantucket, MA: Nantucket Memorial         19.0        2.0
# 3           Alexandria, LA: Alexandria International         88.0       14.0
# 4        Augusta, GA: Augusta Regional at Bush Field        181.0       19.0
#
#    carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  arr_cancelled  \
# 0        5.95        0.00  ...          0.0              1.00            0.0
# 1        7.38        0.00  ...          0.0              6.09            0.0
# 2        0.13        0.00  ...          0.0              0.88            1.0
# 3        7.26        0.76  ...          0.0              1.64            0.0
# 4       13.84        0.00  ...          0.0              2.09            0.0
#
#    arr_diverted  arr_delay  carrier_delay  weather_delay  nas_delay  \
# 0           0.0      255.0          222.0            0.0        4.0
# 1           0.0      884.0          351.0            0.0       81.0
# 2           0.0      138.0            4.0            0.0      106.0
# 3           0.0      947.0          585.0           35.0      125.0
# 4           0.0      808.0          662.0            0.0       87.0
#
#    security_delay  late_aircraft_delay
# 0             0.0                 29.0
# 1             0.0                452.0
# 2             0.0                 28.0
# 3             0.0                202.0
# 4             0.0                 59.0
#
# [5 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318017 entries, 0 to 318016
# Data columns (total 21 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   year                 318017 non-null  int64
#  1   month                318017 non-null  int64
#  2   carrier              318013 non-null  object
#  3   carrier_name         318013 non-null  object
#  4   airport              318014 non-null  object
#  5   airport_name         318017 non-null  object
#  6   arr_flights          317524 non-null  float64
#  7   arr_del15            317285 non-null  float64
#  8   carrier_ct           317525 non-null  float64
#  9   weather_ct           317523 non-null  float64
#  10  nas_ct               317529 non-null  float64
#  11  security_ct          317529 non-null  float64
#  12  late_aircraft_ct     317529 non-null  float64
#  13  arr_cancelled        317529 non-null  float64
#  14  arr_diverted         317527 non-null  float64
#  15  arr_delay            317523 non-null  float64
#  16  carrier_delay        317525 non-null  float64
#  17  weather_delay        317529 non-null  float64
#  18  nas_delay            317529 non-null  float64
#  19  security_delay       317527 non-null  float64
#  20  late_aircraft_delay  317529 non-null  float64
# dtypes: float64(15), int64(2), object(4)
# memory usage: 51.0+ MB

# %%
data = data.drop(['carrier','carrier_name','airport','airport_name'],axis=1)
data
# Out:
#         year  month  arr_flights  arr_del15  carrier_ct  weather_ct  nas_ct  \
# 0       2022      5        136.0        7.0        5.95        0.00    0.05
# 1       2022      5         91.0       16.0        7.38        0.00    2.54
# 2       2022      5         19.0        2.0        0.13        0.00    1.00
# 3       2022      5         88.0       14.0        7.26        0.76    4.35
# 4       2022      5        181.0       19.0       13.84        0.00    3.07
# ...      ...    ...          ...        ...         ...         ...     ...
# 318012  2003      6        480.0       84.0       25.69        3.09   33.96
# 318013  2003      6        505.0      111.0       21.78        2.24   73.81
# 318014  2003      6        146.0       36.0        6.99        0.00   26.85
# 318015  2003      6         95.0       13.0        3.66        0.00    7.92
# 318016  2003      6       3466.0      454.0      121.15        7.61  221.91
#
#         security_ct  late_aircraft_ct  arr_cancelled  arr_diverted  arr_delay  \
# 0               0.0              1.00            0.0           0.0      255.0
# 1               0.0              6.09            0.0           0.0      884.0
# 2               0.0              0.88            1.0           0.0      138.0
# 3               0.0              1.64            0.0           0.0      947.0
# 4               0.0              2.09            0.0           0.0      808.0
# ...             ...               ...            ...           ...        ...
# 318012          0.0             21.26            0.0           0.0     3744.0
# 318013          0.0             13.17            3.0           0.0     4284.0
# 318014          0.0              2.15            0.0           0.0      896.0
# 318015          0.0              1.42            0.0           0.0      367.0
# 318016          1.0            102.33            9.0           0.0    16853.0
#
#         carrier_delay  weather_delay  nas_delay  security_delay  \
# 0               222.0            0.0        4.0             0.0
# 1               351.0            0.0       81.0             0.0
# 2                 4.0            0.0      106.0             0.0
# 3               585.0           35.0      125.0             0.0
# 4               662.0            0.0       87.0             0.0
# ...               ...            ...        ...             ...
# 318012          978.0          164.0     1023.0             0.0
# 318013         1376.0          138.0     2132.0             0.0
# 318014          205.0            0.0      607.0             0.0
# 318015          120.0            0.0      210.0             0.0
# 318016         5384.0          306.0     5686.0            28.0
#
#         late_aircraft_delay
# 0                      29.0
# 1                     452.0
# 2                      28.0
# 3                     202.0
# 4                      59.0
# ...                     ...
# 318012               1579.0
# 318013                638.0
# 318014                 84.0
# 318015                 37.0
# 318016               5449.0
#
# [318017 rows x 17 columns]

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 317268 entries, 0 to 318016
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   year                 317268 non-null  int64
#  1   month                317268 non-null  int64
#  2   arr_flights          317268 non-null  float64
#  3   arr_del15            317268 non-null  float64
#  4   carrier_ct           317268 non-null  float64
#  5   weather_ct           317268 non-null  float64
#  6   nas_ct               317268 non-null  float64
#  7   security_ct          317268 non-null  float64
#  8   late_aircraft_ct     317268 non-null  float64
#  9   arr_cancelled        317268 non-null  float64
#  10  arr_diverted         317268 non-null  float64
#  11  arr_delay            317268 non-null  float64
#  12  carrier_delay        317268 non-null  float64
#  13  weather_delay        317268 non-null  float64
#  14  nas_delay            317268 non-null  float64
#  15  security_delay       317268 non-null  float64
#  16  late_aircraft_delay  317268 non-null  float64
# dtypes: float64(15), int64(2)
# memory usage: 43.6 MB

# %%
data['weather_delay'].min(),data['weather_delay'].max()
# Out:
# (0.0, 57707.0)

# %%
data['WDCase'] = data['weather_delay'].apply(lambda x : 1 if x >100 else 0)

# %%
data['WDCase'].value_counts()
# Out:
# 0    215116
# 1    102152
# Name: WDCase, dtype: int64

# %%
data
# Out:
#         year  month  arr_flights  arr_del15  carrier_ct  weather_ct  nas_ct  \
# 0       2022      5        136.0        7.0        5.95        0.00    0.05
# 1       2022      5         91.0       16.0        7.38        0.00    2.54
# 2       2022      5         19.0        2.0        0.13        0.00    1.00
# 3       2022      5         88.0       14.0        7.26        0.76    4.35
# 4       2022      5        181.0       19.0       13.84        0.00    3.07
# ...      ...    ...          ...        ...         ...         ...     ...
# 318012  2003      6        480.0       84.0       25.69        3.09   33.96
# 318013  2003      6        505.0      111.0       21.78        2.24   73.81
# 318014  2003      6        146.0       36.0        6.99        0.00   26.85
# 318015  2003      6         95.0       13.0        3.66        0.00    7.92
# 318016  2003      6       3466.0      454.0      121.15        7.61  221.91
#
#         security_ct  late_aircraft_ct  arr_cancelled  arr_diverted  arr_delay  \
# 0               0.0              1.00            0.0           0.0      255.0
# 1               0.0              6.09            0.0           0.0      884.0
# 2               0.0              0.88            1.0           0.0      138.0
# 3               0.0              1.64            0.0           0.0      947.0
# 4               0.0              2.09            0.0           0.0      808.0
# ...             ...               ...            ...           ...        ...
# 318012          0.0             21.26            0.0           0.0     3744.0
# 318013          0.0             13.17            3.0           0.0     4284.0
# 318014          0.0              2.15            0.0           0.0      896.0
# 318015          0.0              1.42            0.0           0.0      367.0
# 318016          1.0            102.33            9.0           0.0    16853.0
#
#         carrier_delay  weather_delay  nas_delay  security_delay  \
# 0               222.0            0.0        4.0             0.0
# 1               351.0            0.0       81.0             0.0
# 2                 4.0            0.0      106.0             0.0
# 3               585.0           35.0      125.0             0.0
# 4               662.0            0.0       87.0             0.0
# ...               ...            ...        ...             ...
# 318012          978.0          164.0     1023.0             0.0
# 318013         1376.0          138.0     2132.0             0.0
# 318014          205.0            0.0      607.0             0.0
# 318015          120.0            0.0      210.0             0.0
# 318016         5384.0          306.0     5686.0            28.0
#
#         late_aircraft_delay  WDCase
# 0                      29.0       0
# 1                     452.0       0
# 2                      28.0       0
# 3                     202.0       0
# 4                      59.0       0
# ...                     ...     ...
# 318012               1579.0       1
# 318013                638.0       1
# 318014                 84.0       0
# 318015                 37.0       0
# 318016               5449.0       1
#
# [317268 rows x 18 columns]

# %%
X = data.drop(['WDCase'],axis = 1)
y =data['WDCase']

# %%
import tensorflow as tf
import keras

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=44, shuffle =True)

print('X_train shape is ' , X_train.shape)
print('X_test shape is ' , X_test.shape)
print('y_train shape is ' , y_train.shape)
print('y_test shape is ' , y_test.shape)
# Out:
# X_train shape is  (237951, 17)
# X_test shape is  (79317, 17)
# y_train shape is  (237951,)
# y_test shape is  (79317,)

# %%
KerasModel = keras.models.Sequential([
                # keras.layers.Input(shape=(17)),
            keras.layers.Dense(8,  activation = 'tanh'),
            # keras.layers.Dropout(0.1),
            keras.layers.Dense(128, activation = 'sigmoid'),
            # keras.layers.Dropout(0.3),
            keras.layers.Dense(64, activation = 'tanh'),
            keras.layers.Dense(32, activation = 'tanh'),
            keras.layers.Dropout(0.2),
            keras.layers.Dense(1, activation = 'sigmoid')
            ])

# %%
MyOptimizer = tf.keras.optimizers.experimental.AdamW(
    learning_rate=0.001,
    weight_decay=0.004,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    amsgrad=False,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    jit_compile=True,
    name="AdamW")

# %%
KerasModel.compile(optimizer =MyOptimizer,loss='binary_crossentropy',metrics=['accuracy']) # matrix

# %%
history = KerasModel.fit(X_train,y_train,
                         validation_data=(X_test,y_test),
                         epochs=100,
                         batch_size=10000,
                         verbose=1,
                         callbacks=[tf.keras.callbacks.EarlyStopping(
                                            patience=10,
                                            monitor='val_accuracy',#"val_loss",
                                            restore_best_weights=True)])
# Out:
# Epoch 1/100
# 24/24 [==============================] - 3s 53ms/step - loss: 0.6200 - accuracy: 0.6634 - val_loss: 0.5479 - val_accuracy: 0.6773
# Epoch 2/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.5006 - accuracy: 0.7390 - val_loss: 0.4585 - val_accuracy: 0.7776
# Epoch 3/100
# 24/24 [==============================] - 1s 40ms/step - loss: 0.4505 - accuracy: 0.7799 - val_loss: 0.4378 - val_accuracy: 0.7884
# Epoch 4/100
# 24/24 [==============================] - 0s 21ms/step - loss: 0.4321 - accuracy: 0.7925 - val_loss: 0.4228 - val_accuracy: 0.7956
# Epoch 5/100
# 24/24 [==============================] - 1s 24ms/step - loss: 0.4179 - accuracy: 0.8009 - val_loss: 0.4105 - val_accuracy: 0.8031
# Epoch 6/100
# 24/24 [==============================] - 1s 28ms/step - loss: 0.4048 - accuracy: 0.8067 - val_loss: 0.3966 - val_accuracy: 0.8089
# Epoch 7/100
# 24/24 [==============================] - 1s 40ms/step - loss: 0.3874 - accuracy: 0.8123 - val_loss: 0.3751 - val_accuracy: 0.8142
# Epoch 8/100
# 24/24 [==============================] - 1s 23ms/step - loss: 0.3632 - accuracy: 0.8343 - val_loss: 0.3453 - val_accuracy: 0.8547
# Epoch 9/100
# 24/24 [==============================] - 1s 23ms/step - loss: 0.3076 - accuracy: 0.8833 - val_loss: 0.2561 - val_accuracy: 0.9122
# Epoch 10/100
# 24/24 [==============================] - 0s 21ms/step - loss: 0.2022 - accuracy: 0.9333 - val_loss: 0.1653 - val_accuracy: 0.9402
# Epoch 11/100
# 24/24 [==============================] - 1s 22ms/step - loss: 0.1402 - accuracy: 0.9562 - val_loss: 0.1228 - val_accuracy: 0.9608
# Epoch 12/100
# 24/24 [==============================] - 0s 20ms/step - loss: 0.1123 - accuracy: 0.9668 - val_loss: 0.0916 - val_accuracy: 0.9730
# Epoch 13/100
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0885 - accuracy: 0.9761 - val_loss: 0.0701 - val_accuracy: 0.9814
# Epoch 14/100
# 24/24 [==============================] - 0s 21ms/step - loss: 0.0629 - accuracy: 0.9838 - val_loss: 0.0522 - val_accuracy: 0.9870
# Epoch 15/100
# 24/24 [==============================] - 0s 21ms/step - loss: 0.0394 - accuracy: 0.9905 - val_loss: 0.0301 - val_accuracy: 0.9925
# Epoch 16/100
# 24/24 [==============================] - 1s 21ms/step - loss: 0.0269 - accuracy: 0.9942 - val_loss: 0.0247 - val_accuracy: 0.9946
# Epoch 17/100
# 24/24 [==============================] - 1s 21ms/step - loss: 0.0331 - accuracy: 0.9930 - val_loss: 0.0401 - val_accuracy: 0.9901
# Epoch 18/100
# 24/24 [==============================] - 0s 21ms/step - loss: 0.0316 - accuracy: 0.9927 - val_loss: 0.0207 - val_accuracy: 0.9951
# Epoch 19/100
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0198 - accuracy: 0.9958 - val_loss: 0.0192 - val_accuracy: 0.9955
# Epoch 20/100
# 24/24 [==============================] - 0s 21ms/step - loss: 0.0189 - accuracy: 0.9960 - val_loss: 0.0188 - val_accuracy: 0.9958
# Epoch 21/100
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0234 - accuracy: 0.9951 - val_loss: 0.0194 - val_accuracy: 0.9957
# Epoch 22/100
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0239 - accuracy: 0.9952 - val_loss: 0.0284 - val_accuracy: 0.9937
# Epoch 23/100
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0206 - accuracy: 0.9957 - val_loss: 0.0201 - val_accuracy: 0.9957
# Epoch 24/100
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0178 - accuracy: 0.9962 - val_loss: 0.0178 - val_accuracy: 0.9963
# Epoch 25/100
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0181 - accuracy: 0.9962 - val_loss: 0.0167 - val_accuracy: 0.9963
# Epoch 26/100
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0198 - accuracy: 0.9958 - val_loss: 0.0192 - val_accuracy: 0.9953
# Epoch 27/100
# 24/24 [==============================] - 0s 21ms/step - loss: 0.0232 - accuracy: 0.9951 - val_loss: 0.0276 - val_accuracy: 0.9947
# Epoch 28/100
# 24/24 [==============================] - 1s 21ms/step - loss: 0.0262 - accuracy: 0.9945 - val_loss: 0.0159 - val_accuracy: 0.9969
# Epoch 29/100
# 24/24 [==============================] - 0s 21ms/step - loss: 0.0158 - accuracy: 0.9967 - val_loss: 0.0163 - val_accuracy: 0.9967
# Epoch 30/100
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0150 - accuracy: 0.9969 - val_loss: 0.0155 - val_accuracy: 0.9966
# Epoch 31/100
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0177 - accuracy: 0.9962 - val_loss: 0.0175 - val_accuracy: 0.9966
# Epoch 32/100
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0156 - accuracy: 0.9967 - val_loss: 0.0199 - val_accuracy: 0.9963
# Epoch 33/100
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0189 - accuracy: 0.9961 - val_loss: 0.0179 - val_accuracy: 0.9961
# Epoch 34/100
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0143 - accuracy: 0.9970 - val_loss: 0.0154 - val_accuracy: 0.9966
# Epoch 35/100
# 24/24 [==============================] - 0s 21ms/step - loss: 0.0139 - accuracy: 0.9970 - val_loss: 0.0145 - val_accuracy: 0.9970
# Epoch 36/100
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0133 - accuracy: 0.9972 - val_loss: 0.0130 - val_accuracy: 0.9972
# Epoch 37/100
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0120 - accuracy: 0.9975 - val_loss: 0.0119 - val_accuracy: 0.9975
# Epoch 38/100
# 24/24 [==============================] - 1s 36ms/step - loss: 0.0127 - accuracy: 0.9973 - val_loss: 0.0130 - val_accuracy: 0.9972
# Epoch 39/100
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0133 - accuracy: 0.9973 - val_loss: 0.0143 - val_accuracy: 0.9972
# Epoch 40/100
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0138 - accuracy: 0.9971 - val_loss: 0.0142 - val_accuracy: 0.9967
# Epoch 41/100
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0120 - accuracy: 0.9974 - val_loss: 0.0113 - val_accuracy: 0.9976
# Epoch 42/100
# 24/24 [==============================] - 0s 21ms/step - loss: 0.0151 - accuracy: 0.9969 - val_loss: 0.0252 - val_accuracy: 0.9952
# Epoch 43/100
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0138 - accuracy: 0.9971 - val_loss: 0.0114 - val_accuracy: 0.9977
# Epoch 44/100
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0152 - accuracy: 0.9969 - val_loss: 0.0138 - val_accuracy: 0.9972
# Epoch 45/100
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0108 - accuracy: 0.9977 - val_loss: 0.0121 - val_accuracy: 0.9974
# Epoch 46/100
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0113 - accuracy: 0.9976 - val_loss: 0.0152 - val_accuracy: 0.9971
# Epoch 47/100
# 24/24 [==============================] - 0s 21ms/step - loss: 0.0145 - accuracy: 0.9969 - val_loss: 0.0124 - val_accuracy: 0.9969
# Epoch 48/100
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0139 - accuracy: 0.9971 - val_loss: 0.0116 - val_accuracy: 0.9977
# Epoch 49/100
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0103 - accuracy: 0.9979 - val_loss: 0.0120 - val_accuracy: 0.9974
# Epoch 50/100
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0194 - accuracy: 0.9957 - val_loss: 0.0119 - val_accuracy: 0.9976
# Epoch 51/100
# 24/24 [==============================] - 1s 21ms/step - loss: 0.0135 - accuracy: 0.9971 - val_loss: 0.0100 - val_accuracy: 0.9978
# Epoch 52/100
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0096 - accuracy: 0.9979 - val_loss: 0.0116 - val_accuracy: 0.9977
# Epoch 53/100
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0088 - accuracy: 0.9982 - val_loss: 0.0085 - val_accuracy: 0.9981
# Epoch 54/100
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0094 - accuracy: 0.9979 - val_loss: 0.0106 - val_accuracy: 0.9979
# Epoch 55/100
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0161 - accuracy: 0.9968 - val_loss: 0.0152 - val_accuracy: 0.9966
# Epoch 56/100
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0162 - accuracy: 0.9967 - val_loss: 0.0188 - val_accuracy: 0.9963
# Epoch 57/100
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0194 - accuracy: 0.9961 - val_loss: 0.0122 - val_accuracy: 0.9972
# Epoch 58/100
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0098 - accuracy: 0.9979 - val_loss: 0.0100 - val_accuracy: 0.9979
# Epoch 59/100
# 24/24 [==============================] - 1s 21ms/step - loss: 0.0094 - accuracy: 0.9980 - val_loss: 0.0096 - val_accuracy: 0.9979
# Epoch 60/100
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0084 - accuracy: 0.9981 - val_loss: 0.0186 - val_accuracy: 0.9966
# Epoch 61/100
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0117 - accuracy: 0.9975 - val_loss: 0.0074 - val_accuracy: 0.9983
# Epoch 62/100
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0084 - accuracy: 0.9981 - val_loss: 0.0090 - val_accuracy: 0.9979
# Epoch 63/100
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0172 - accuracy: 0.9965 - val_loss: 0.0198 - val_accuracy: 0.9953
# Epoch 64/100
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0120 - accuracy: 0.9975 - val_loss: 0.0165 - val_accuracy: 0.9967
# Epoch 65/100
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0099 - accuracy: 0.9979 - val_loss: 0.0076 - val_accuracy: 0.9983
# Epoch 66/100
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0081 - accuracy: 0.9982 - val_loss: 0.0125 - val_accuracy: 0.9975
# Epoch 67/100
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0075 - accuracy: 0.9984 - val_loss: 0.0088 - val_accuracy: 0.9981
# Epoch 68/100
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0188 - accuracy: 0.9961 - val_loss: 0.0130 - val_accuracy: 0.9974
# Epoch 69/100
# 24/24 [==============================] - 1s 21ms/step - loss: 0.0086 - accuracy: 0.9982 - val_loss: 0.0078 - val_accuracy: 0.9982
# Epoch 70/100
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0161 - accuracy: 0.9968 - val_loss: 0.0296 - val_accuracy: 0.9926
# Epoch 71/100
# 24/24 [==============================] - 1s 21ms/step - loss: 0.0147 - accuracy: 0.9969 - val_loss: 0.0091 - val_accuracy: 0.9983

# %%
KerasModel.save('KerasModel.model')
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: KerasModel.model\assets
# INFO:tensorflow:Assets written to: KerasModel.model\assets

# %%
NewKerasModel = keras.models.load_model('KerasModel.model')

# %%
X_test
# Out:
#         year  month  arr_flights  arr_del15  carrier_ct  weather_ct  nas_ct  \
# 256596  2007      1        213.0       64.0       16.33        3.44   15.06
# 6930    2022      1        617.0       82.0       29.69        2.04   26.88
# 125951  2014     11         62.0        8.0        3.00        0.00    2.09
# 87817   2017     10         82.0        9.0        6.00        1.20    1.00
# 42037   2020      3        168.0       12.0        6.65        2.00    1.04
# ...      ...    ...          ...        ...         ...         ...     ...
# 132929  2014      5       2410.0      637.0      222.01        9.35   56.16
# 251541  2007      4         42.0        8.0        5.83        0.00    1.50
# 84057   2018      1         80.0       12.0        3.48        3.92    0.12
# 32889   2020     10        356.0       23.0        8.12        0.00   10.33
# 269836  2006      4       1075.0      181.0       56.35        1.40   82.43
#
#         security_ct  late_aircraft_ct  arr_cancelled  arr_diverted  arr_delay  \
# 256596         0.00             29.17           13.0           0.0     3840.0
# 6930           0.30             23.08           27.0           1.0     5410.0
# 125951         0.00              2.91            0.0           0.0      609.0
# 87817          0.00              0.80            0.0           0.0      260.0
# 42037          0.00              2.31           19.0           0.0      558.0
# ...             ...               ...            ...           ...        ...
# 132929         0.85            348.62           13.0           0.0    34346.0
# 251541         0.00              0.67            1.0           0.0      306.0
# 84057          0.00              4.48            2.0           0.0     1060.0
# 32889          0.00              4.56            0.0           2.0      989.0
# 269836         0.77             40.05            4.0           2.0     7544.0
#
#         carrier_delay  weather_delay  nas_delay  security_delay  \
# 256596          912.0          292.0      720.0             0.0
# 6930           2471.0          157.0     1095.0            15.0
# 125951          391.0            0.0      123.0             0.0
# 87817           201.0           22.0       17.0             0.0
# 42037           331.0           73.0       43.0             0.0
# ...               ...            ...        ...             ...
# 132929         9518.0          842.0     2427.0            38.0
# 251541          234.0            0.0       58.0             0.0
# 84057            97.0          721.0       13.0             0.0
# 32889           516.0            0.0      260.0             0.0
# 269836         2914.0           78.0     2205.0            75.0
#
#         late_aircraft_delay
# 256596               1916.0
# 6930                 1672.0
# 125951                 95.0
# 87817                  20.0
# 42037                 111.0
# ...                     ...
# 132929              21521.0
# 251541                 14.0
# 84057                 229.0
# 32889                 213.0
# 269836               2272.0
#
# [79317 rows x 17 columns]

# %%
y_pred = NewKerasModel.predict(X_test)
# Out:
# 2479/2479 [==============================] - 9s 3ms/step

# %%
print('Prediction Shape is {}'.format(y_pred.shape))
# Out:
# Prediction Shape is (79317, 1)

# %%
print('Prediction items are {}'.format(y_pred[:5]))
# Out:
# Prediction items are [[9.9830091e-01]
#  [9.9830091e-01]
#  [2.1150730e-04]
#  [2.1150730e-04]
#  [1.3242675e-03]]

# %%
ModelLoss, ModelAccuracy = NewKerasModel.evaluate(X_test, y_test)
print('Model Loss is {}'.format(ModelLoss))
print('Model Accuracy is {}'.format(ModelAccuracy ))
# Out:
# 2479/2479 [==============================] - 5s 2ms/step - loss: 0.0074 - accuracy: 0.9983
# Model Loss is 0.007364138029515743
# Model Accuracy is 0.9983105659484863

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
